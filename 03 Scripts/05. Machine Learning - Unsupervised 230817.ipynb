# %% [markdown]
# ### Table of contents
# 01. Importing Libraries and Importing Data Set
# 02. Cleaning
# 03. Elbow Method to assess number of clusters
# 04. Applying kmeans with the cluster recomendation from the elbow method
# 05. Plotting clusters and examining data

# %% [markdown]
# # 01. Importing Libraries and Data Sets

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.cluster import KMeans # Here is where you import the k-means algorithm from scikit-learn.
import pylab as pl # PyLab is a convenience module that bulk imports matplotlib.

# %%
# cleaned flight data with all NaN values removed which inadvertantly removes all cancelled and diverted flights. Delays can still be assessed
delays = pd.read_csv('/Users/tuor/DA Projects/230616 2019 delayed with flight time.csv')

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 02. Cleaning

# %%
# reviewing data imported
delays
# Out:
#         Unnamed: 0  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER OP_CARRIER  \
# 0                0             1            2                9E         9E
# 1                1             1            2                9E         9E
# 2                2             1            2                9E         9E
# 3                3             1            2                9E         9E
# 4                4             1            2                9E         9E
# ...            ...           ...          ...               ...        ...
# 612556      612556            31            4                UA         UA
# 612557      612557            31            4                UA         UA
# 612558      612558            31            4                UA         UA
# 612559      612559            31            4                UA         UA
# 612560      612560            31            4                UA         UA
#
#        TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN DEST  DEP_TIME  DEP_DEL15  \
# 0        N8688C               3280    GNV  ATL       601        0.0
# 1        N348PQ               3281    MSP  CVG      1359        0.0
# 2        N8896A               3282    DTW  CVG      1215        0.0
# 3        N8886A               3283    TLH  ATL      1521        0.0
# 4        N8974C               3284    ATL  FSM      1847        0.0
# ...         ...                ...    ...  ...       ...        ...
# 612556   N776UA                200    GUM  HNL       749        0.0
# 612557   N36280                174    GUM  SPN       717        0.0
# 612558   N36280                117    SPN  GUM       857        0.0
# 612559   N39726                105    SPN  GUM      1820        0.0
# 612560   N39726                104    GUM  SPN      1636        0.0
#
#        DEP_TIME_BLK  ARR_TIME  ARR_DEL15  DISTANCE  ORIGIN_CITY  \
# 0         0600-0659       722        0.0     300.0  Gainesville
# 1         1400-1459      1633        0.0     596.0  Minneapolis
# 2         1200-1259      1329        0.0     229.0      Detroit
# 3         1500-1559      1625        0.0     223.0  Tallahassee
# 4         1900-1959      1940        0.0     579.0      Atlanta
# ...             ...       ...        ...       ...          ...
# 612556    0700-0759      1832        0.0    3801.0     Tamuning
# 612557    0700-0759       759        0.0     129.0     Tamuning
# 612558    0900-0959       933        0.0     129.0       Saipan
# 612559    1800-1859      1854        0.0     129.0       Saipan
# 612560    1600-1659      1719        0.0     129.0     Tamuning
#
#           ORIGIN_STATE_OR_REGION ORIGIN_FULL_NAME  GMT_DEP   DEST_CITY  \
# 0                             FL          Florida        5     Atlanta
# 1                             MN        Minnesota        6  Cincinnati
# 2                             MI         Michigan        5  Cincinnati
# 3                             FL          Florida        5     Atlanta
# 4                             GA          Georgia        5  Fort Smith
# ...                          ...              ...      ...         ...
# 612556                      Guam             Guam       10    Honolulu
# 612557                      Guam             Guam       10      Saipan
# 612558  Northern Mariana Islands              NaN       10    Tamuning
# 612559  Northern Mariana Islands              NaN       10    Tamuning
# 612560                      Guam             Guam       10      Saipan
#
#             DEST_STATE_OR_REGION DEST_FULL_NAME  GMT_ARR  dep_hour  arr_hour  \
# 0                             GA        Georgia        5         6         7
# 1                             OH           Ohio        5        13        16
# 2                             OH           Ohio        5        12        13
# 3                             GA        Georgia        5        15        16
# 4                             AR       Arkansas        6        18        19
# ...                          ...            ...      ...       ...       ...
# 612556                  Oahu, HI         Hawaii       10         7        18
# 612557  Northern Mariana Islands            NaN       10         7         7
# 612558                      Guam           Guam       10         8         9
# 612559                      Guam           Guam       10        18        18
# 612560  Northern Mariana Islands            NaN       10        16        17
#
#         flt_time_min ORIGIN/DEST
# 0               81.0      GNVATL
# 1               94.0      MSPCVG
# 2               74.0      DTWCVG
# 3               64.0      TLHATL
# 4              113.0      ATLFSM
# ...              ...         ...
# 612556         643.0      GUMHNL
# 612557          42.0      GUMSPN
# 612558          36.0      SPNGUM
# 612559          34.0      SPNGUM
# 612560          43.0      GUMSPN
#
# [612561 rows x 27 columns]

# %%
# removing secondary index column
delays = delays.drop(['Unnamed: 0'],axis=1)

# %%
# grabbing only relavent numerical data
delays_num = delays[['DISTANCE', 'flt_time_min']]
# delays_num = delays[['DISTANCE', 'flt_time_min']]

# %%
# grabbing keeping the main part of the database
delays_rest = delays[['DAY_OF_MONTH','DAY_OF_WEEK', 'DEP_TIME', 'ARR_TIME', 'DISTANCE', 'flt_time_min']]
# delays_num = delays[['DISTANCE', 'flt_time_min']]

# %% [markdown]
# # 03. Elbow Method to assess number of clusters

# %%
num_cl = range(1, 10) # Defines the range of potential clusters in the data.
kmeans = [KMeans(n_clusters=i) for i in num_cl] # Defines k-means clusters in the range assigned above.

# %%
score = [kmeans[i].fit(delays_num).score(delays_num) for i in range(len(kmeans))] # Creates a score that represents 
# a rate of variation for the given cluster option.

score
# Out:
# [-213806381875.04352,
#  -73441057827.84946,
#  -33155006081.693657,
#  -20224063759.967583,
#  -12632103044.17521,
#  -10028227020.212006,
#  -7647719480.733309,
#  -5882055417.377808,
#  -4569658527.383859]

# %%
# Plot the elbow curve using PyLab.

pl.plot(num_cl,score)
pl.xlabel('Number of Clusters')
pl.ylabel('Score')
pl.title('Elbow Curve')
pl.show()

# %% [markdown]
# Massive jump from 2 to 3 and curve begins to flatten out, though a little dramatically. Will start with 3 clusters.

# %% [markdown]
# # 04. Applying kmeans with the cluster recomendation from the elbow method

# %%
# Create the k-means object.

kmeans = KMeans(n_clusters = 3)

# %%
delays_num['clusters'] = kmeans.fit_predict(delays_num)
# Out:
# /var/folders/lr/bnypmrgd10lfz8x9hx1x8w9w0000gn/T/ipykernel_8390/2353659519.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delays_num['clusters'] = kmeans.fit_predict(delays_num)

# %%
delays_num.head()
# Out:
#    DISTANCE  flt_time_min  clusters
# 0     300.0          81.0         1
# 1     596.0          94.0         1
# 2     229.0          74.0         1
# 3     223.0          64.0         1
# 4     579.0         113.0         1

# %% [markdown]
# # 05. Plotting clusters and examining data

# %%
delays_num['clusters'].value_counts()
# Out:
# 1    333817
# 0    212217
# 2     66527
# Name: clusters, dtype: int64

# %%
# Plot the clusters for the "Distance" and "Flight time in min" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=delays_num['DISTANCE'], y=delays_num['flt_time_min'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Distance Traveled') # Label x-axis.
plt.ylabel('Flight Time (Min)') # Label y-axis.
plt.show()

# %% [markdown]
# Dark Purple holds the widest spread and greatest distances
# Pink and Purple are highly concentrated in shorter range flights and are the largest groups. If nothing else it shows that the vast majority of flights occur below 1500 miles.

# %%
# Plot the clusters for the "Distance" and "Flight time in min" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=delays_num['DISTANCE'], y=delays_num['DAY_OF_WEEK'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Distance Traveled') # Label x-axis.
plt.ylabel('Day of Week') # Label y-axis.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DAY_OF_WEEK'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/lr/bnypmrgd10lfz8x9hx1x8w9w0000gn/T/ipykernel_8390/1422679867.py in <module>
#       2
#       3 plt.figure(figsize=(12,8))
# ----> 4 ax = sns.scatterplot(x=delays_num['DISTANCE'], y=delays_num['DAY_OF_WEEK'], hue=kmeans.labels_, s=100)
#       5 # Here, you're subsetting `X` for the x and y arguments to avoid using their labels.
#       6 # `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'DAY_OF_WEEK'

# %% [markdown]
# The groups seem to be pretty evenly spread across days of the week

# %%
# Plot the clusters for the "Distance" and "Flight time in min" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=delays_num['flt_time_min'], y=delays_num['DEP_TIME'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Distance Traveled') # Label x-axis.
plt.ylabel('Flight Time') # Label y-axis.
plt.show()

# %% [markdown]
# Since purple is one of the largest groups it is easy to see that the concentration of flights is between 1500 and 2300 and is shorter flights largerly. Longer flights seem to leave at all times and there is clearly few to no flights in the 3-4am time. Extreme distance seem to only fly after 10am as well.

# %%
# Plot the clusters for the "Distance" and "Flight time in min" variables.

plt.figure(figsize=(12,8))
ax = sns.scatterplot(x=delays_num['DAY_OF_WEEK'], y=delays_num['DEP_TIME'], hue=kmeans.labels_, s=100) 
# Here, you're subsetting `X` for the x and y arguments to avoid using their labels. 
# `hue` takes the value of the attribute `kmeans.labels_`, which is the result of running the k-means algorithm.
# `s` represents the size of the points you want to see in the plot.

ax.grid(False) # This removes the grid from the background.
plt.xlabel('Day of Week') # Label x-axis.
plt.ylabel('Departure Time') # Label y-axis.
plt.show()

# %% [markdown]
# Judging by dark purples spread I would say that most days of the week long distance flights occur at extreme times except on day 3 and 4. Given the previous grouping these flights include a large numer of the 1500-2000 mile flights.

# %%
delays_num.loc[delays_num['clusters'] == 2, 'cluster'] = 'dark purple'
delays_num.loc[delays_num['clusters'] == 1, 'cluster'] = 'purple'
delays_num.loc[delays_num['clusters'] == 0, 'cluster'] = 'pink'
# Out:
# /var/folders/lr/bnypmrgd10lfz8x9hx1x8w9w0000gn/T/ipykernel_8390/3114340285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delays_num.loc[delays_num['clusters'] == 2, 'cluster'] = 'dark purple'

# %%
delays_num.groupby('cluster').agg({'DAY_OF_MONTH':['mean', 'median'], 
                         'DAY_OF_WEEK':['mean', 'median'], 
                         'DEP_TIME':['mean', 'median'],
                          'ARR_TIME':['mean', 'median'],
                          'DISTANCE': ['mean', 'median'],
                          'flt_time_min':['mean', 'median']})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lr/bnypmrgd10lfz8x9hx1x8w9w0000gn/T/ipykernel_8390/2384110644.py in <module>
# ----> 1 delays_num.groupby('cluster').agg({'DAY_OF_MONTH':['mean', 'median'],
#       2                          'DAY_OF_WEEK':['mean', 'median'],
#       3                          'DEP_TIME':['mean', 'median'],
#       4                           'ARR_TIME':['mean', 'median'],
#       5                           'DISTANCE': ['mean', 'median'],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     867
#     868         op = GroupByApply(self, func, args, kwargs)
# --> 869         result = op.agg()
#     870         if not is_dict_like(func) and result is not None:
#     871             return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg(self)
#     166
#     167         if is_dict_like(arg):
# --> 168             return self.agg_dict_like()
#     169         elif is_list_like(arg):
#     170             # we require a list, but not a 'str'
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in agg_dict_like(self)
#     471             selection = obj._selection
#     472
# --> 473         arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     474
#     475         if selected_obj.ndim == 1:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in normalize_dictlike_arg(self, how, obj, func)
#     589             if len(cols) > 0:
#     590                 cols_sorted = list(safe_sort(list(cols)))
# --> 591                 raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     592
#     593         is_aggregator = lambda x: isinstance(x, (list, tuple, dict))
#
# KeyError: "Column(s) ['ARR_TIME', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'DEP_TIME'] do not exist"

# %%
merged_df = delays_num.merge(delays_rest, left_index=True, right_index=True)

# %%
merged_df.head()
# Out:
#    DISTANCE_x  flt_time_min_x  clusters cluster  DAY_OF_MONTH  DAY_OF_WEEK  \
# 0       300.0            81.0         1  purple             1            2
# 1       596.0            94.0         1  purple             1            2
# 2       229.0            74.0         1  purple             1            2
# 3       223.0            64.0         1  purple             1            2
# 4       579.0           113.0         1  purple             1            2
#
#    DEP_TIME  ARR_TIME  DISTANCE_y  flt_time_min_y
# 0       601       722       300.0            81.0
# 1      1359      1633       596.0            94.0
# 2      1215      1329       229.0            74.0
# 3      1521      1625       223.0            64.0
# 4      1847      1940       579.0           113.0

# %%
merged_df.rename(columns={'DISTANCE_x': 'Distance', 'flt_time_min_x': 'Flight Time (Minutes)'}, inplace=True)

# %%
# ML data exporting to .csv
merged_df.to_csv('/Users/tuor/DA Projects/230817 2019 ML Unspervised Data.csv')

# %%
merged_df.head()
# Out:
#    Distance  Flight Time (Minutes)  clusters cluster  DAY_OF_MONTH  \
# 0     300.0                   81.0         1  purple             1
# 1     596.0                   94.0         1  purple             1
# 2     229.0                   74.0         1  purple             1
# 3     223.0                   64.0         1  purple             1
# 4     579.0                  113.0         1  purple             1
#
#    DAY_OF_WEEK  DEP_TIME  ARR_TIME  DISTANCE_y  flt_time_min_y
# 0            2       601       722       300.0            81.0
# 1            2      1359      1633       596.0            94.0
# 2            2      1215      1329       229.0            74.0
# 3            2      1521      1625       223.0            64.0
# 4            2      1847      1940       579.0           113.0
